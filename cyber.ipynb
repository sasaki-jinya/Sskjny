# %%
from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set()
import statsmodels.api as sm
import datetime
import matplotlib.dates as mdates

# %%
import os
path = os.getcwd()
print(path)
# Out:
# C:\home

# %%
os.chdir('../')

# %%
cyber = read_csv('program/cyber.csv')
print(cyber.head())
# Out:
#     type        Bop         Eop    Sales   pSales
# 0  total  2018/10/1   2019/9/30  453,611  111,759
# 1    3rd  2018/10/1   2019/6/30  341,852  113,668
# 2    2nd  2018/10/1   2019/3/31  228,184  117,329
# 3    1st  2018/10/1  2018/12/31  110,855  110,855
# 4  total  2017/10/1   2018/9/30  419,512  107,552

# %%
cyber = pd.read_csv('program/cyber.csv',index_col='Eop',parse_dates=True, dtype=np.float64)
cyber.head()
# Out:
#                Sales    pSales
# Eop
# 2019-09-30  453611.0  111759.0
# 2019-06-30  341852.0  113668.0
# 2019-03-31  228184.0  117329.0
# 2018-12-31  110855.0  110855.0
# 2018-09-30  419512.0  107552.0

# %%
Sales = cyber[['Sales']]
pSales = cyber[['pSales']]

# %%
plt.plot(Sales)

# %%
plt.plot(pSales)
