# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from requests_oauthlib import OAuth1Session
import tweepy
import json

# %% [markdown]
# ## Twitter key

# %%
consumer_key = "wyy6NjSmY89DZ296RsHiz0jd1"
consumer_secret = "Ls8v0B6dryTErTNkgNgWr6YrYcdSgfA2YlvWmWOfErSLfPWbMs"
access_token = "1206191643113619456-h1dQ9Nq7Tv7LXgwKVA07UsIxGnj2AI"
access_token_secret = "AVht3tKtrWYGlDaUALb7K0zN7wsMNY9NoKIWfDDJQnuy4"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
timeline_url = "https://api.twitter.com/1.1/statuses/user_timeline.json"
tweet_url = "https://api.twitter.com/1.1/search/tweets.json"
twitter = OAuth1Session(consumer_key,consumer_secret,access_token,access_token_secret)

# %% [markdown]
# ## Twitter Display timeline

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# 楽しく働ける理由は何❓
# マクドナルドで働く学生クルーにインタビュー🤗
# クルーへのインタビュー記事はこちら👉 https://t.co/xgjc18vNZR https://t.co/Qx74xT2KPJ
# ＼今年のクリスマス、楽しむならどっち？／
# #メクリマス パーティーならRT🔁❗️クリスマスパーティーならいいね💖してね❗今だけ！ #ビッグマック と #マックフライポテトL なら、めくって嬉しい！食べて美味しい！ #メクリマス… https://t.co/e0VWlGrMdx
# 超人気✨YouTube🌻 #HIMAWARIちゃんねる 🌻ではおうちをゲームのステージに変身させちゃった⁉️隠された #ハッピーセット #スーパーマリオ のおもちゃを探して家族みんなで白熱バトル💥💣 #まーちゃんおーちゃん のお気… https://t.co/1dXCikspR0
# 📣SPECIAL WEEKEND📣今週末限定アイテム #スーパーマリオ の #ハッピーセット でもらえる、なりきりクリアファイル💫‼😍🙌ゲットできるのは今日12/22(日)まで❗😎❗今日の予定に #マクドナルド を入れておこう👍… https://t.co/h9HXAaoWaG
# わーい🙌みんなお待ちかね冬休み✨今年は早めに目標を立てて冬休みをさらに充実💪まずは整理整頓おかたづけから❗✨遊んでいない #ハッピーセット のおもちゃは #マクドナルド にもってきてリサイクルしてね👐✨お部屋をきれいにして2019… https://t.co/TmtrehLvzm
# ＼あなたはどっちで #メクリマス した？／
#  #ビッグマック か #マックフライポテトL 、どっちで多く #メクリマス しましたか？🤣✨ #マックフライポテトL ならRT🔁❗️ #ビッグマック ならいいね💖してね❗️… https://t.co/ufQgC1UGDB
# 大好評の #グラコロ 、もう食べました😆❓ #グラコロソング もぜひ覚えて歌ってみてくださいね♫グラコロがもっとおいしく食べられるかも❗️❓ #あったかいってごほうびだ #音声オンで楽しんでね… https://t.co/ahKAL0xbAy
# ...

# %%
params ={'count' : 5}
req = twitter.get(timeline_url, params = params)

if req.status_code == 200:
    timeline = json.loads(req.text)
    for tweet in timeline:
        print(tweet['user']['name']+'::'+tweet['text'])
        print(tweet['created_at'])
        print('----------------------------------------------------')
else:
    print("ERROR: %d" % req.status_code)
# Out:
# sasaki jinya::NLP test
# Thu Dec 19 04:29:15 +0000 2019
# ----------------------------------------------------
# sasaki jinya::2019/12/1913:28
# Thu Dec 19 04:28:00 +0000 2019
# ----------------------------------------------------

# %% [markdown]
# ## Display keyword

# %%
print("何を調べますか?")
keyword = input('>> ')
print('----------------------------------------------------')

params = {'q' : keyword, 'count' : 5}

req = twitter.get(tweet_url, params = params)

if req.status_code == 200:
    search_timeline = json.loads(req.text)
    for tweet in search_timeline['statuses']:
        print(tweet['user']['name'] + '::' + tweet['text'])
        print(tweet['created_at'])
        print('----------------------------------------------------')
else:
    print("ERROR: %d" % req.status_code)
# Out:
# 何を調べますか?
# >>  人工知能
# ----------------------------------------------------
# 人工知能のニュースや話題::SNSで人気が上がるハッシュタグを人工知能が教えてくれる #AI #人工知能 https://t.co/kRc0Z5hvaM
# Sun Dec 22 12:52:38 +0000 2019
# ----------------------------------------------------
# ききょけら::人工知能搭載人型ロボ《ヒューマギア》が様々な仕事をサポートする新時代。
# AIテクノロジー企業の若き社長が
# 人々の夢を守るため、今 飛び立つ。 https://t.co/CAYNvrKeTV
# Sun Dec 22 12:52:23 +0000 2019
# ----------------------------------------------------
# みゃお::RT @nhk_kabun: あらゆる分野でＡＩ＝人工知能の活用が進み、アメリカでは“ＡＩのバイアス”の議論が始まっています。見えてきたのは、ＡＩが社会の差別を再生産するかもしれないという危機感です。https://t.co/THIg3owX1x
# Sun Dec 22 12:51:06 +0000 2019
# ----------------------------------------------------
# あちゃま！::えーあい？
# 人工知能？？！
# 奪ってないよ
#
# #Peing #質問箱 https://t.co/gxhGl5i7yT
# Sun Dec 22 12:50:46 +0000 2019
# ----------------------------------------------------
# 【乞食】🎄moririn🌙.*·̩͙::RT @henjo_official: 🎉🎉新規カラー画像を追加しました🎉🎉
# おっぱいとリプライするだけで、おっぱいもらえます。
#
# ※変女botの最近のツイートをRTしておくと、画像が人工知能着色のカラーおっぱいになりますよ！ https://t.co/K3u92RzMfm
# ...

# %% [markdown]
# ## Display Trend

# %%
woeid = {
    "北九州": 1110809,"埼玉": 1116753, "千葉": 1117034, "浜松":1117155,"川崎": 1117502,"大阪": 15015370,
    "広島": 1117227, "福岡": 1117099, "沖縄": 2345896,"神戸":1117545,"熊本":1117605,"名古屋":1117817,
    "新潟":1117881,"相模原":1118072,"高松":1118285,"横浜":1118550,"京都":15015372,"日本": 23424856
}

for area, wid in woeid.items():
    print("--- {} ---".format(area))
    # リストになっているので取り出す
    trends = api.trends_place(wid)[0]
    #print(trends.keys()) # trends, as_of, created_at, locations
    #print(len(trends["trends"])) # 50
    for i, content in enumerate(trends["trends"]):
        print(i+1, content['name'])
    print("----------")
# Out:
# --- 北九州 ---
# 1 #M1グランプリ2019
# 2 コーンフレーク
# 3 インディアンス
# 4 オズワルド
# 5 #グランメゾン東京
# 6 羽生くん
# 7 宇野くん
# 8 #私のストロング芸人
# 9 敗者復活
# 10 審査員
# 11 上沼さん
# 12 #ライガー総選挙
# 13 上沼恵美子
# 14 鍵山くん
# 15 コンビ
# 16 #大神ミオ新衣装
# 17 昌磨くん
# 18 ぺこぱ好き
# 19 しょーま
# 20 甲賀忍法帖
# 21 ゆず湯
# 22 イッテQ
# 23 バジリスクタイム
# 24 横浜スタジアム
# 25 池の水
# 26 ギンギラ銀河
# 27 世界選手権
# 28 柚子湯
# 29 M-1レベル
# 30 E-girls
# 31 四千頭身
# 32 駒ちゃん
# 33 雪まつり
# 34 月スタ
# 35 和牛の2本目
# 36 和牛好き
# 37 天竺鼠
# 38 羽生君
# 39 #欅坂46わたしの始まりの1曲
# 40 #ガルパ生
# 41 #全日本フィギュアスケート選手権2019
# 42 #ツイキャス座談会2019
# 43 #行列のできる法律相談所
# 44 #鉄腕DASH
# 45 #東京リボーン
# ----------
# --- 埼玉 ---
# 1 #M1グランプリ2019
# 2 コーンフレーク
# 3 インディアンス
# 4 オズワルド
# 5 #グランメゾン東京
# 6 羽生くん
# 7 宇野くん
# 8 #私のストロング芸人
# 9 敗者復活
# 10 審査員
# 11 上沼さん
# 12 #ライガー総選挙
# 13 上沼恵美子
# 14 鍵山くん
# 15 コンビ
# 16 #大神ミオ新衣装
# 17 昌磨くん
# 18 ぺこぱ好き
# 19 しょーま
# 20 甲賀忍法帖
# 21 ゆず湯
# 22 イッテQ
# 23 バジリスクタイム
# 24 横浜スタジアム
# 25 池の水
# 26 ギンギラ銀河
# 27 世界選手権
# 28 柚子湯
# 29 M-1レベル
# 30 E-girls
# 31 四千頭身
# 32 駒ちゃん
# 33 雪まつり
# 34 月スタ
# 35 和牛の2本目
# 36 和牛好き
# 37 天竺鼠
# 38 羽生選手
# ...

# %% [markdown]
# ## file Display

# %%
import emoji

def remove_emoji(src_str):
    return ''.join(c for c in src_str if c not in emoji.UNICODE_EMOJI)

# %%
params2 = {'screen_name': '@g031p068siwate1',
          'exclude_replies': True,
          'include_rts': False,
          'count': 200}
print("何を調べますか?")
keyword = input('>> ')
print('----------------------------------------------------')

params = {'q' : keyword, 'count' : 5}

j=0
# 出力先ファイル
f_out = open('tweet_data', 'w')

for j in range(100):
    print(res.status_code)
    res = twitter.get(tweet_url, params=params)
    if res.status_code == 200:
        # API残り回数
        limit = res.headers['x-rate-limit-remaining']
        print("API remain: " + limit)
        if limit == 1:
            sleep(60*15)

        n = 0
        timeline = json.loads(res.text)
        # 各ツイートの本文を表示
        for i in range(len(timeline)):
            if i != len(timeline)-1:
                f_out.write(remove_emoji(timeline[i]['text']) + '\n')
            else:
                f_out.write(remove_emoji(timeline[i]['text']) + '\n')
                params2['max_id'] = timeline[i]['id']-1

f_out.close()
# Out:
# 何を調べますか?
# >>  人工知能
# ----------------------------------------------------
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429

# %%
res.status_code
# Out:
# 429
