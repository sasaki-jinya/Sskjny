# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense,  LSTM,  Dropout
# %matplotlib inline
from keras import metrics
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from plot_keras_history import plot_history
# Out:
# Using TensorFlow backend.
# C:\home\anaconda\envs\TF\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import os
path = os.getcwd()
print(path)
# Out:
# C:\home\program

# %%
os.chdir('../')

# %%
df = pd.read_csv('program/stock2.csv', encoding="shift_jis")
df['day'] = pd.to_datetime(df['day'], format='%Y/%m/%d')
timeSeries = df.loc[:, ["day","end"]]
timeSeries.index = timeSeries.day
ts = timeSeries.drop("day",axis=1)

# %%
df.set_index('day')
dateTimeIndex = pd.DatetimeIndex(df['day'])
df.index = dateTimeIndex
df[df.index.duplicated(keep=False)]
# Out:
#                   day   start   hight     low     end
# day
# 2019-04-01 2019-04-01  3340.0  3390.0  3330.0  3380.0
# 2019-04-01 2019-04-01  3340.0  3390.0  3330.0  3380.0

# %%
print(ts.index.get_loc("2019-04-01"))
# Out:
# slice(489, 491, None)

# %%
df = df.drop(df.index[[489]])

# %%
df = df.resample('D').interpolate()

# %%
df['day']=df.index

# %%
L = len(df)
Y = df.iloc[:, 4]  # 終値の列のみ抽出する。
Y = np.array(Y)  # numpy配列に変換する。
Y = Y.reshape(-1, 1)  # 行列に変換する。（配列の要素数行×1列）

# %%
X1 = Y[0:L-3, :]  # 予測対象日の3日前のデータ
X2 = Y[1:L-2, :]  # 予測対象日の2日前のデータ
X3 = Y[2:L-1, :]  # 予測対象日の前日データ
Y = Y[3:L, :]  # 予測対象日のデータ
X = np.concatenate([X1, X2, X3], axis=1)  # numpy配列を結合する。

# %%
scaler = MinMaxScaler()  # データを0～1の範囲にスケールするための関数。
scaler.fit(X)  # スケーリングに使用する最小／最大値を計算する。
X = scaler.transform(X)  # Xをを0～1の範囲にスケーリングする。

# %%
scaler1 = MinMaxScaler()  # データを0～1の範囲にスケールするための関数。
scaler1.fit(Y)  # スケーリングに使用する最小／最大値を計算する。
Y = scaler1.transform(Y)  # Yをを0～1の範囲にスケーリングする。

# %%
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))  # 3次元配列に変換する。

# %%
# train, testデータを定義
X_train = X[:500, :, :]
X_test = X[500:, :, :]
Y_train = Y[:500, :]
Y_test = Y[500:, :]

# %%
model = Sequential()
model.add(LSTM(10, activation = 'tanh', input_shape = (1,3), recurrent_activation= 'hard_sigmoid'))
model.add(Dense(1))

# %%
model.compile(loss= 'mean_squared_error', optimizer = 'rmsprop', metrics=[metrics.mae])
history = model.fit(X_train, Y_train, epochs=50, verbose=2).history
plot_history(history)
Predict = model.predict(X_test)
# Out:
# Epoch 1/50
#  - 0s - loss: 0.5604 - mean_absolute_error: 0.7458
# Epoch 2/50
#  - 0s - loss: 0.4229 - mean_absolute_error: 0.6478
# Epoch 3/50
#  - 0s - loss: 0.3166 - mean_absolute_error: 0.5600
# Epoch 4/50
#  - 0s - loss: 0.2252 - mean_absolute_error: 0.4718
# Epoch 5/50
#  - 0s - loss: 0.1484 - mean_absolute_error: 0.3821
# Epoch 6/50
#  - 0s - loss: 0.0873 - mean_absolute_error: 0.2921
# Epoch 7/50
#  - 0s - loss: 0.0427 - mean_absolute_error: 0.2020
# Epoch 8/50
#  - 0s - loss: 0.0153 - mean_absolute_error: 0.1171
# Epoch 9/50
#  - 0s - loss: 0.0033 - mean_absolute_error: 0.0480
# Epoch 10/50
#  - 0s - loss: 8.8378e-04 - mean_absolute_error: 0.0225
# Epoch 11/50
#  - 0s - loss: 7.7088e-04 - mean_absolute_error: 0.0212
# Epoch 12/50
#  - 0s - loss: 7.7557e-04 - mean_absolute_error: 0.0215
# Epoch 13/50
#  - 0s - loss: 7.3709e-04 - mean_absolute_error: 0.0209
# Epoch 14/50
#  - 0s - loss: 7.3093e-04 - mean_absolute_error: 0.0208
# Epoch 15/50
#  - 0s - loss: 7.1225e-04 - mean_absolute_error: 0.0204
# Epoch 16/50
#  - 0s - loss: 6.9804e-04 - mean_absolute_error: 0.0203
# Epoch 17/50
#  - 0s - loss: 6.7958e-04 - mean_absolute_error: 0.0200
# Epoch 18/50
#  - 0s - loss: 6.3414e-04 - mean_absolute_error: 0.0194
# Epoch 19/50
#  - 0s - loss: 6.1498e-04 - mean_absolute_error: 0.0190
# Epoch 20/50
#  - 0s - loss: 6.0140e-04 - mean_absolute_error: 0.0189
# Epoch 21/50
#  - 0s - loss: 5.9569e-04 - mean_absolute_error: 0.0187
# Epoch 22/50
#  - 0s - loss: 5.6481e-04 - mean_absolute_error: 0.0182
# Epoch 23/50
#  - 0s - loss: 5.6928e-04 - mean_absolute_error: 0.0184
# Epoch 24/50
#  - 0s - loss: 5.3044e-04 - mean_absolute_error: 0.0176
# Epoch 25/50
#  - 0s - loss: 5.0842e-04 - mean_absolute_error: 0.0172
# Epoch 26/50
#  - 0s - loss: 5.0377e-04 - mean_absolute_error: 0.0172
# Epoch 27/50
#  - 0s - loss: 4.8791e-04 - mean_absolute_error: 0.0169
# Epoch 28/50
#  - 0s - loss: 4.7937e-04 - mean_absolute_error: 0.0165
# Epoch 29/50
#  - 0s - loss: 4.8147e-04 - mean_absolute_error: 0.0167
# Epoch 30/50
#  - 0s - loss: 4.6185e-04 - mean_absolute_error: 0.0164
# Epoch 31/50
#  - 0s - loss: 4.7244e-04 - mean_absolute_error: 0.0161
# Epoch 32/50
#  - 0s - loss: 4.4691e-04 - mean_absolute_error: 0.0161
# Epoch 33/50
#  - 0s - loss: 4.5480e-04 - mean_absolute_error: 0.0163
# Epoch 34/50
#  - 0s - loss: 4.3266e-04 - mean_absolute_error: 0.0158
# Epoch 35/50
#  - 0s - loss: 4.2330e-04 - mean_absolute_error: 0.0156
# Epoch 36/50
#  - 0s - loss: 4.1684e-04 - mean_absolute_error: 0.0153
# Epoch 37/50
#  - 0s - loss: 4.0683e-04 - mean_absolute_error: 0.0151
# Epoch 38/50
#  - 0s - loss: 3.9989e-04 - mean_absolute_error: 0.0151
# Epoch 39/50
#  - 0s - loss: 3.9280e-04 - mean_absolute_error: 0.0150
# Epoch 40/50
#  - 0s - loss: 3.9811e-04 - mean_absolute_error: 0.0151
# Epoch 41/50
#  - 0s - loss: 3.7324e-04 - mean_absolute_error: 0.0145
# Epoch 42/50
#  - 0s - loss: 3.7668e-04 - mean_absolute_error: 0.0147
# Epoch 43/50
#  - 0s - loss: 3.7917e-04 - mean_absolute_error: 0.0146
# Epoch 44/50
#  - 0s - loss: 3.6711e-04 - mean_absolute_error: 0.0145
# Epoch 45/50
#  - 0s - loss: 3.6286e-04 - mean_absolute_error: 0.0143
# Epoch 46/50
#  - 0s - loss: 3.4627e-04 - mean_absolute_error: 0.0141
# Epoch 47/50
#  - 0s - loss: 3.6170e-04 - mean_absolute_error: 0.0143
# Epoch 48/50
#  - 0s - loss: 3.3794e-04 - mean_absolute_error: 0.0137
# Epoch 49/50
#  - 0s - loss: 3.6797e-04 - mean_absolute_error: 0.0145
# Epoch 50/50
#  - 0s - loss: 3.4090e-04 - mean_absolute_error: 0.0138

# %%
# オリジナルのスケールに戻す、タイムインデックスを付ける。
Y_train = scaler1.inverse_transform(Y_train)
Y_train = pd.DataFrame(Y_train)
Y_train.index = pd.to_datetime(df.iloc[3:503,0])

# %%
Y_test = scaler1.inverse_transform(Y_test)
Y_test = pd.DataFrame(Y_test)
Y_test.index = pd.to_datetime(df.iloc[503:,0])

# %%
Predict = scaler1.inverse_transform(Predict)
Predict = pd.DataFrame(Predict)
Predict.index=pd.to_datetime(df.iloc[503:,0])

# %%
plt.figure(figsize=(22,10))
plt.plot(Y_test, label = 'Test')
plt.plot(Predict, label = 'Prediction')
plt.legend(loc='best')
plt.show()

# %%
df['day'] = pd.to_datetime(df['day'], format='%Y/%m/%d')
timeSeries = df.loc[:, ["day","end"]]
timeSeries.index = timeSeries.day
ts = timeSeries.drop("day",axis=1)

# %%
ts[ts.index.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [end]
# Index: []

# %%
print(ts.index.get_loc("2019-04-01"))
# Out:
# 728

# %%
ts = ts.drop(ts.index[[489]])

# %%
ts[ts.index.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [end]
# Index: []

# %%
ts = ts.resample('D').interpolate()

# %%
from statsmodels.tsa.arima_model import ARIMA

arima_model = ARIMA(Predict[0], order=(2,0,2)).fit(dist=False)
arima_model2 = ARIMA(ts, order=(2,0,2)).fit(dist=False)
# Out:
# C:\home\anaconda\envs\TF\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# C:\home\anaconda\envs\TF\lib\site-packages\statsmodels\base\model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
arima_model2.summary()
# Out:
# C:\home\anaconda\envs\TF\lib\site-packages\statsmodels\tsa\arima_model.py:1441: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(-inv(hess)))
# C:\home\anaconda\envs\TF\lib\site-packages\scipy\stats\_distn_infrastructure.py:1932: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                    end   No. Observations:                 1152
# Model:                     ARMA(2, 2)   Log Likelihood               -6041.717
# Method:                       css-mle   S.D. of innovations             45.725
# Date:                Mon, 03 Aug 2020   AIC                          12095.435
# Time:                        12:35:41   BIC                          12125.730
# Sample:                    04-03-2017   HQIC                         12106.870
#                          - 05-28-2020
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2756.4837        nan        nan        nan         nan         nan
# ar.L1.end      1.1594      0.065     17.758      0.000       1.031       1.287
# ar.L2.end     -0.1601      0.065     -2.454      0.014      -0.288      -0.032
# ma.L1.end     -0.0386      0.071     -0.541      0.588      -0.178       0.101
# ma.L2.end      0.0489      0.031      1.577      0.115      -0.012       0.110
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0008           +0.0000j            1.0008            0.0000
# AR.2            6.2425           +0.0000j            6.2425            0.0000
# MA.1            0.3945           -4.5060j            4.5233           -0.2361
# MA.2            0.3945           +4.5060j            4.5233            0.2361
# -----------------------------------------------------------------------------
# """

# %%
forecast = arima_model.predict()
forecast2 = arima_model2.predict()

# %%
y_forecasted = np.exp(arima_model2.predict()/10)
y_truth = np.exp(Y_test['2018-09-05':'2020-05-28']/10)

# %%
y_truth[0]
# Out:
# day
# 2018-09-05    7.078985e+210
# 2018-09-06    1.050614e+213
# 2018-09-07    1.050614e+213
# 2018-09-08    3.373807e+213
# 2018-09-09    1.083421e+214
#                   ...
# 2020-05-24    4.780206e+104
# 2020-05-25    2.530875e+105
# 2020-05-26    2.266473e+109
# 2020-05-27    2.768276e+109
# 2020-05-28    1.113919e+113
# Name: 0, Length: 632, dtype: float64

# %%
rmse = np.sqrt(((y_forecasted - y_truth[0]) ** 2).mean())
print('RMSE = {}'.format(round(rmse, 4)))
# Out:
# RMSE = inf

# %%
plt.figure(figsize=(22,10))
plt.plot(Y_test, label = 'Test')
plt.plot(forecast,label = "lstm-ARIMA")
plt.plot(forecast2,label = "ARIMA")
#plt.plot(forecast3,label = "lstm-ARIMA--5")
#plt.plot(forecast4,label = "ARIMA--5")
plt.plot(Predict, label = 'lstm')
plt.title("Time Series Forecast")
plt.xlabel("day")
plt.ylabel("終値")
plt.legend()
plt.show()
# Out:
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32066 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32066 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20516 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(22,10))
plt.plot(Y_test, label = 'Test')
plt.plot(forecast,label = "lstm-ARIMA")
plt.plot(forecast2,label = "ARIMA")
plt.plot(Predict, label = 'lstm')
plt.title("Time Series Forecast")
plt.xlabel("day")
plt.ylabel("終値")
plt.legend()
plt.show()

# %%
LA_error = forecast-Y_test[0]
A_error = forecast2-Y_test[0]
L_error = Predict[0]-Y_test[0]
zero = Y_test
zero[0] = 0

# %%
LA_rows_to_drop = LA_error.index[LA_error >= 500]
A_rows_to_drop = A_error.index[A_error >= 500]
L_rows_to_drop = L_error.index[L_error >= 500]

# %%
LA = LA_error.drop(LA_rows_to_drop)
A = A_error.drop(A_rows_to_drop)
L = L_error.drop(L_rows_to_drop)

# %%
plt.figure(figsize=(22,10))
plt.plot(LA_error,label = "lstm-ARIMA")
plt.plot(A_error,label = "ARIMA")
plt.plot(L_error,label = "lstm")
plt.plot(zero,label = "zero")
plt.title("値の変化")
plt.xlabel("day")
plt.ylabel("終値")
plt.legend()
plt.show()
# Out:
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(22,10))
plt.plot(LA,label = "lstm-ARIMA")
plt.plot(A,label = "ARIMA")
plt.plot(L,label = "lstm")
plt.plot(zero,label = "zero")
plt.title("値の変化-drop")
plt.xlabel("day")
plt.ylabel("終値")
plt.legend()
plt.show()

# %%
LA_rows_to_drop
# Out:
# DatetimeIndex(['2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#                '2020-03-13', '2020-03-14', '2020-04-02', '2020-05-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
A_rows_to_drop
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', name='day', freq=None)

# %%
L_rows_to_drop
# Out:
# DatetimeIndex(['2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#                '2020-03-13', '2020-03-14', '2020-05-15'],
#               dtype='datetime64[ns]', name='day', freq=None)

# %%
forecast.drop(LA_rows_to_drop)
forecast2.drop(A_rows_to_drop)
Predict[0].drop(L_rows_to_drop)
# Out:
# day
# 2018-08-19    4975.978516
# 2018-08-20    5004.496094
# 2018-08-21    5007.454590
# 2018-08-22    4953.488281
# 2018-08-23    4895.972168
#                  ...
# 2020-05-24    2735.943115
# 2020-05-25    2737.449463
# 2020-05-26    2749.538574
# 2020-05-27    2782.346924
# 2020-05-28    2805.688721
# Name: 0, Length: 642, dtype: float32

# %%
forecast.resample('D').interpolate()
forecast2.resample('D').interpolate()
Predict[0].resample('D').interpolate()
# Out:
# day
# 2018-08-19    4975.978516
# 2018-08-20    5004.496094
# 2018-08-21    5007.454590
# 2018-08-22    4953.488281
# 2018-08-23    4895.972168
#                  ...
# 2020-05-24    2735.943115
# 2020-05-25    2737.449463
# 2020-05-26    2749.538574
# 2020-05-27    2782.346924
# 2020-05-28    2805.688721
# Freq: D, Name: 0, Length: 649, dtype: float32

# %%
Y_test = Y[500:, :]

Y_test = scaler1.inverse_transform(Y_test)
Y_test = pd.DataFrame(Y_test)
Y_test.index = pd.to_datetime(df.iloc[503:,0])

# %%
plt.figure(figsize=(22,10))
plt.plot(Y_test, label = 'Test')
plt.plot(forecast,label = "lstm-ARIMA")
plt.plot(forecast2,label = "ARIMA")
plt.plot(Predict, label = 'lstm')
plt.title("Time Series Forecast")
plt.xlabel("day")
plt.ylabel("終値")
plt.legend()
plt.show()
# Out:
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32066 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32066 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20516 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
LA_error = forecast-Y_test[0]
A_error = forecast2-Y_test[0]
L_error = Predict[0]-Y_test[0]

# %%
plt.figure(figsize=(22,10))
plt.plot(LA,label = "lstm-ARIMA")
plt.plot(A,label = "ARIMA")
plt.plot(L,label = "lstm")
plt.plot(zero,label = "zero")
plt.title("値の変化-drop")
plt.xlabel("day")
plt.ylabel("終値")
plt.legend()
plt.show()
# Out:
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 22793 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\home\anaconda\envs\TF\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21270 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
LA_rows_to_drop_250 = LA_error.index[LA_error >= 250]
A_rows_to_drop_250 = A_error.index[A_error >= 250]
L_rows_to_drop_250 = L_error.index[L_error >= 250]

# %%
LA_rows_to_drop_250[208]
# Out:
# Timestamp('2020-04-01 00:00:00')

# %%
year_2018 = LA_rows_to_drop_250[0:6]

# %%
year_2019 = LA_rows_to_drop_250[7:207]

# %%
year_2020 = LA_rows_to_drop_250[208:]

# %%
plt.figure(figsize=(22,10))
plt.plot(forecast[year_2018],label = "lstm-ARIMA")
plt.plot(Y_test['2018-08-19':'2019-03-30'],label = "test")
plt.title("2018")
plt.xlabel("day")
plt.ylabel("終値")
plt.legend()
plt.show()
